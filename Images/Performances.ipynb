# %% [markdown]
# # Performance on balanced datasets

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patheffects as path_effects

# Random Negative Samples - Unseen Edges 

# %matplotlib inline

#means1 = np.array([0.8092, 0.5939, 0.6439, 0.5057, 0.52])
means1 = np.array([0.81, 0.59, 0.64, 0.51, 0.52])
stdvs1 = np.array([0.0104, 0.0265, 0.0137, 0.0014, 0.0])
#means2 = np.array([0.8348, 0.6023, 0.6399, 0.2415, 0.26])
means2 = np.array([0.83, 0.60, 0.64, 0.24, 0.26])
stdvs2 = np.array([0.0064, 0.0245, 0.0134, 0.0026, 0.0])

fig, ax = plt.subplots(1,1,figsize=(3,4), dpi=300)
ax.hlines(list(range(len(means1))), means1-(stdvs1),
          means1+(stdvs1), color='crimson')
ax.scatter(means1, list(range(len(means1))), marker='s', s=10,
           color='crimson', label='ROC-AUC', ec='.1', zorder=2)
ax.hlines(np.array(list(range(len(means2))))-0.2,
          means2-(stdvs2), means2+(stdvs2),
          color='darksalmon')
ax.scatter(means2, np.array(list(range(len(means2))))-0.2,
           marker='s', s=10, color='darksalmon', label='Average Precision', ec='.1', zorder=2)
for mi,m in enumerate(means1):
    ax.text((means1-(stdvs1)/((means1)**.5))[mi]-0.025, list(range(len(means1)))[mi],
           m, ha='right', va='center',color='crimson', path_effects=[path_effects.Stroke(linewidth=1.5, foreground='w'),
                           path_effects.Normal()])
for mi,m in enumerate(means2):
    ax.text((means2-(stdvs2)/((means2)**.5))[mi]-0.025, list(range(len(means2)))[mi]-0.2,
           m, ha='right', va='center',color='darksalmon', path_effects=[path_effects.Stroke(linewidth=1.5, foreground='w'),
                           path_effects.Normal()])
ax.legend(loc=2, bbox_to_anchor=[0.1, -0.125], ncol=2, framealpha=0)
ax.set_yticks([-0.1,0.9,1.9,2.9,3.9])
ax.set_yticklabels(['VecNet','Siamese','VAENet','DeepPurpose', 'Configuration Model'])
ax.grid(axis='x', lw=1.5, alpha=0.3, color='.75')
ax.set_xlabel('Performance')
ax.set_xlim(0,1)
plt.show()

# %%
# Random Negative Samples - Unseen Targets

# %matplotlib inline

#means1 = np.array([0.6648, 0.5964, 0.5837, 0.5216, 0.51])
means1 = np.array([0.66, 0.60, 0.58, 0.52, 0.51])
stdvs1 = np.array([0.0272, 0.03565, 0.0206, 0.0026, 0.0])
#means2 = np.array([0.6734, 0.5695,  0.5568, 0.2670,  0.25])
means2 = np.array([0.67, 0.57, 0.56, 0.27, 0.25])
stdvs2 = np.array([0.0182, 0.0463, 0.0182, 0.0011, 0.0])

fig, ax = plt.subplots(1,1,figsize=(3,4), dpi=300)
ax.hlines(list(range(len(means1))), means1-(stdvs1),
          means1+(stdvs1), color='crimson')
ax.scatter(means1, list(range(len(means1))), marker='s', s=10,
           color='crimson', label='ROC-AUC', ec='.1', zorder=2)
ax.hlines(np.array(list(range(len(means2))))-0.2,
          means2-(stdvs2), means2+(stdvs2),
          color='darksalmon')
ax.scatter(means2, np.array(list(range(len(means2))))-0.2,
           marker='s', s=10, color='darksalmon', label='Average Precision', ec='.1', zorder=2)
for mi,m in enumerate(means1):
    ax.text((means1-(stdvs1)/((means1)**.5))[mi]-0.025, list(range(len(means1)))[mi],
           m, ha='right', va='center',color='crimson', path_effects=[path_effects.Stroke(linewidth=1.5, foreground='w'),
                           path_effects.Normal()])
for mi,m in enumerate(means2):
    ax.text((means2-(stdvs2)/((means2)**.5))[mi]-0.025, list(range(len(means2)))[mi]-0.2,
           m, ha='right', va='center',color='darksalmon', path_effects=[path_effects.Stroke(linewidth=1.5, foreground='w'),
                           path_effects.Normal()])
ax.legend(loc=2, bbox_to_anchor=[0.1, -0.125], ncol=2, framealpha=0)
ax.set_yticks([-0.1,0.9,1.9,2.9,3.9])
ax.set_yticklabels(['VecNet','Siamese','VAENet','DeepPurpose', 'Configuration Model'])
ax.grid(axis='x', lw=1.5, alpha=0.3, color='.75')
ax.set_xlabel('Performance')
ax.set_xlim(0,1)
plt.show()

# %%
# 9-Hop Negative Samples - Unseen Edges

# %matplotlib inline

#means1 = np.array([0.8604, 0.6965, 0.8278, 0.7465, 0.59])
means1 = np.array([0.86, 0.70, 0.83, 0.75, 0.59])
stdvs1 = np.array([0.0048, 0.0169, 0.0048, 0.0199, 0.0])
#means2 = np.array([0.8396, 0.67904, 0.8213, 0.7767, 0.35])
means2 = np.array([0.84, 0.68, 0.82, 0.78, 0.35])
stdvs2 = np.array([0.0090, 0.0205, 0.0145, 0.0162, 0.0])

fig, ax = plt.subplots(1,1,figsize=(3,4), dpi=300)
ax.hlines(list(range(len(means1))), means1-(stdvs1),
          means1+(stdvs1), color='crimson')
ax.scatter(means1, list(range(len(means1))), marker='s', s=10,
           color='crimson', label='AUC', ec='.1', zorder=2)
ax.hlines(np.array(list(range(len(means2))))-0.2,
          means2-(stdvs2), means2+(stdvs2),
          color='darksalmon')
ax.scatter(means2, np.array(list(range(len(means2))))-0.2,
           marker='s', s=10, color='darksalmon', label='AUP', ec='.1', zorder=2)
for mi,m in enumerate(means1):
    ax.text((means1-(stdvs1)/((means1)**.5))[mi]-0.025, list(range(len(means1)))[mi],
           m, ha='right', va='center',color='crimson', path_effects=[path_effects.Stroke(linewidth=1.5, foreground='w'),
                           path_effects.Normal()])
for mi,m in enumerate(means2):
    ax.text((means2-(stdvs2)/((means2)**.5))[mi]-0.025, list(range(len(means2)))[mi]-0.2,
           m, ha='right', va='center',color='darksalmon', path_effects=[path_effects.Stroke(linewidth=1.5, foreground='w'),
                           path_effects.Normal()])
ax.legend(loc=2, bbox_to_anchor=[0.1, -0.125], ncol=2, framealpha=0)
ax.set_yticks([-0.1,0.9,1.9,2.9,3.9])
ax.set_yticklabels(['VecNet','Siamese','VAENet','DeepPurpose', 'Configuration Model'])
ax.grid(axis='x', lw=1.5, alpha=0.3, color='.75')
ax.set_xlabel('Performance')
ax.set_xlim(0,1)
plt.show()

# %%
# 9-Hop Negative Samples - Unseen Targets

# %matplotlib inline

#means1 = np.array([0.8074, 0.6987, 0.7969, 0.6031, 0.59])
means1 = np.array([0.81, 0.70, 0.79, 0.60, 0.59])
stdvs1 = np.array([0.0242, 0.0233, 0.0132, 0.0116, 0.0])
#means2 = np.array([0.7702, 0.6528, 0.7662, 0.5949, 0.36])
means2 = np.array([0.77, 0.65, 0.77, 0.59, 0.36])
stdvs2 = np.array([0.0287, 0.0336, 0.0155, 0.0301, 0.0])

fig, ax = plt.subplots(1,1,figsize=(3,4), dpi=300)
ax.hlines(list(range(len(means1))), means1-(stdvs1),
          means1+(stdvs1), color='crimson')
ax.scatter(means1, list(range(len(means1))), marker='s', s=10,
           color='crimson', label='AUC', ec='.1', zorder=2)
ax.hlines(np.array(list(range(len(means2))))-0.2,
          means2-(stdvs2), means2+(stdvs2),
          color='darksalmon')
ax.scatter(means2, np.array(list(range(len(means2))))-0.2,
           marker='s', s=10, color='darksalmon', label='AUP', ec='.1', zorder=2)
for mi,m in enumerate(means1):
    ax.text((means1-(stdvs1)/((means1)**.5))[mi]-0.025, list(range(len(means1)))[mi],
           m, ha='right', va='center',color='crimson', path_effects=[path_effects.Stroke(linewidth=1.5, foreground='w'),
                           path_effects.Normal()])
for mi,m in enumerate(means2):
    ax.text((means2-(stdvs2)/((means2)**.5))[mi]-0.025, list(range(len(means2)))[mi]-0.2,
           m, ha='right', va='center',color='darksalmon', path_effects=[path_effects.Stroke(linewidth=1.5, foreground='w'),
                           path_effects.Normal()])
ax.legend(loc=2, bbox_to_anchor=[0.1, -0.125], ncol=2, framealpha=0)
ax.set_yticks([-0.1,0.9,1.9,2.9,3.9])
ax.set_yticklabels(['VecNet','Siamese','VAENet','DeepPurpose', 'Configuration Model'])
ax.grid(axis='x', lw=1.5, alpha=0.3, color='.75')
ax.set_xlabel('Performance')
ax.set_xlim(0,1)
plt.show()

# %% [markdown]
# # False positive prediction bias

# %%
G1 = nx.barabasi_albert_graph(100000,1)
G2 = nx.barabasi_albert_graph(100000,1)
degs1 = np.array(list(dict(G1.degree()).values()))
degs2 = np.array(list(dict(G2.degree()).values()))
maxbin = max([max(np.log10(degs1)),max(np.log10(degs2))])
hist1, bins1 = np.histogram(np.log10(degs1), bins=10)
hist2, bins2 = np.histogram(np.log10(degs2), bins=bins1)
A = nx.to_numpy_array(nx.erdos_renyi_graph(9, .3))
fig, ax = plt.subplots(1,2,figsize=(8,3), dpi=300,
                       gridspec_kw={'width_ratios':[1,1.5]})
plt.subplots_adjust(wspace=0.4)
ax[0].pcolor(A, ec='.2', cmap='Greys', vmin=0, vmax=3)
fps = [(3, 8), (3, 9), (2,8)]
for fp in fps:
    ax[0].scatter(fp[0]-0.5,fp[1]-0.5,marker='x', color='crimson')
ax[0].set_yticks(np.log10(np.logspace(0, 8, 5, base=10))+0.5)
ax[0].set_yticklabels(np.logspace(0, 8, 5, base=10))
ax[1].bar(bins1[1:]+0.05,hist1, ec='.2',fc='.9', width=0.1, alpha=0.8)
ax[1].bar(bins2[1:]-0.05,hist2, ec='.2',fc='crimson', width=0.1, alpha=0.5)
ax[1].set_yscale('log')
plt.show()

# %% [markdown]
# # Performance  acorss different bins

# %%
import pandas as pd
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from tqdm import tqdm

# %%
edges = pd.read_csv('/data/sars-busters-consolidated/nw_files/WholeNetworkEdgesTable.csv')
edges = edges.rename(columns={'Source':'source','Target':'target'})

# %%
def drop_zeros(a_list):
    return [i for i in a_list if i>0]

def log_binning(counter_dict,bin_count=35):

    max_x = np.log(max(list(counter_dict.keys())))
    max_y = np.log(max(list(counter_dict.values())))
    max_base = max([max_x,max_y])

    min_x = np.log10(min(drop_zeros(list(counter_dict.keys()))))

    bins = np.logspace(min_x,max_base,num=bin_count)

    bin_means_y = (np.histogram(list(counter_dict.keys()),bins,weights=list(counter_dict.values()))[0] / np.histogram(list(counter_dict.keys()),bins)[0])
    bin_means_x = (np.histogram(list(counter_dict.keys()),bins,weights=list(counter_dict.keys()))[0] / np.histogram(list(counter_dict.keys()),bins)[0])

    return bin_means_x,bin_means_y

# %%
def log_binning_distribution(x_i,B = 20): 

    b_1 = min(x_i)
    b_Bp1 = max(x_i)
    q_1 = np.log(b_1)
    q_Bp1 = np.log(b_Bp1)
    D_q = q_Bp1 - q_1
    L_q = D_q / B

    q_list = []
    b_list = []

    for i in range(B):
        j = i + 1
        q_list.append(q_1 + (j-1)*L_q)
        b_list.append(np.exp(q_1 + (j-1)*L_q))

    # b_list.insert(0,b_1)
    b_list.append(b_Bp1)
    
    binned_x_i = []
    density_list = []

    for i in range(len(b_list)-1):
        bin_low = b_list[i]
        bin_high = b_list[i+1]
        count_bin = 0
        for j in range(len(x_i)):
            if x_i[j] >= bin_low and x_i[j] < bin_high:
                count_bin = count_bin + 1
                
        if count_bin > 0:
            density_bin = count_bin / (len(x_i)*(bin_high-bin_low))
            density_list.append(density_bin)
            binned_x_i.append(bin_low)
        else:
            continue 
            
    return binned_x_i, density_list

# %%
unique_targets = set(edges['target'].tolist())

target_degree_dict = dict()

for target_name in tqdm(unique_targets):
    subdf = edges[edges['target'] == target_name]
    target_degree_dict[target_name] = len(subdf)
# Out:
# ...
# 100%|██████████| 5104/5104 [00:03<00:00, 1652.10it/s]

# %%
binned_x_i, density_list = log_binning_distribution(list(target_degree_dict.values()),B = 10)

# %%
plt.loglog(binned_x_i,density_list,'o')
# plt.ylim([0,0.01])

# %%
# Degree bins - Unseen Edges 

# %matplotlib inline

means1 = np.array([0.94,0.87,0.75])
stdvs1 = np.array([0.04481,0.0139,0.0090])

means2 = np.array([0.99,0.99,0.60])
stdvs2 = np.array([0.000009,0.0013,0.0046])

fig, ax = plt.subplots(1,1,figsize=(3,4), dpi=300)
ax.hlines(list(range(len(means1))), means1-(stdvs1),
          means1+(stdvs1), color='crimson')
ax.scatter(means1, list(range(len(means1))), marker='s', s=10,
           color='crimson', label='ROC-AUC', ec='.1', zorder=2)
ax.hlines(np.array(list(range(len(means2))))-0.2,
          means2-(stdvs2), means2+(stdvs2),
          color='darksalmon')
ax.scatter(means2, np.array(list(range(len(means2))))-0.2,
           marker='s', s=10, color='darksalmon', label='Average Precision', ec='.1', zorder=2)
for mi,m in enumerate(means1):
    ax.text((means1-(stdvs1)/((means1)**.5))[mi]-0.025, list(range(len(means1)))[mi],
           m, ha='right', va='center',color='crimson', path_effects=[path_effects.Stroke(linewidth=1.5, foreground='w'),
                           path_effects.Normal()])
for mi,m in enumerate(means2):
    ax.text((means2-(stdvs2)/((means2)**.5))[mi]-0.025, list(range(len(means2)))[mi]-0.2,
           m, ha='right', va='center',color='darksalmon', path_effects=[path_effects.Stroke(linewidth=1.5, foreground='w'),
                           path_effects.Normal()])
ax.legend(loc=2, bbox_to_anchor=[0.1, -0.125], ncol=2, framealpha=0)
ax.set_yticks([-0.1,0.9,1.9])
ax.set_yticklabels(['High Degree','Medium degree','Low Degree'])
ax.grid(axis='x', lw=1.5, alpha=0.3, color='.75')
ax.set_xlabel('Performance')
ax.set_xlim(0,1)
plt.show()

# %%
# Degree bins - Unseen Edges 

# %matplotlib inline

means1 = np.array([0.59,0.70,0.71])
stdvs1 = np.array([0.1547,0.0295,0.0209])

means2 = np.array([0.99,0.97,0.51])
stdvs2 = np.array([0.0008,0.0091,0.02058])

fig, ax = plt.subplots(1,1,figsize=(3,4), dpi=300)
ax.hlines(list(range(len(means1))), means1-(stdvs1),
          means1+(stdvs1), color='crimson')
ax.scatter(means1, list(range(len(means1))), marker='s', s=10,
           color='crimson', label='ROC-AUC', ec='.1', zorder=2)
ax.hlines(np.array(list(range(len(means2))))-0.2,
          means2-(stdvs2), means2+(stdvs2),
          color='darksalmon')
ax.scatter(means2, np.array(list(range(len(means2))))-0.2,
           marker='s', s=10, color='darksalmon', label='Average Precision', ec='.1', zorder=2)
for mi,m in enumerate(means1):
    ax.text((means1-(stdvs1)/((means1)**.5))[mi]-0.025, list(range(len(means1)))[mi],
           m, ha='right', va='center',color='crimson', path_effects=[path_effects.Stroke(linewidth=1.5, foreground='w'),
                           path_effects.Normal()])
for mi,m in enumerate(means2):
    ax.text((means2-(stdvs2)/((means2)**.5))[mi]-0.025, list(range(len(means2)))[mi]-0.2,
           m, ha='right', va='center',color='darksalmon', path_effects=[path_effects.Stroke(linewidth=1.5, foreground='w'),
                           path_effects.Normal()])
ax.legend(loc=2, bbox_to_anchor=[0.1, -0.125], ncol=2, framealpha=0)
ax.set_yticks([-0.1,0.9,1.9])
ax.set_yticklabels(['High Degree','Medium degree','Low Degree'])
ax.grid(axis='x', lw=1.5, alpha=0.3, color='.75')
ax.set_xlabel('Performance')
ax.set_xlim(0,1)
plt.show()

# %%
fig, ax = plt.subplots(1,2,figsize=(8,3), dpi=300,
                       gridspec_kw={'width_ratios':[1,1.5]})
plt.subplots_adjust(wspace=0.4)
ax[0].scatter(bins1[1:], hist1, marker='o', c=['teal']*3+['orange']*5+['crimson']*2, ec='.2')
ax[0].set_yscale('log')
ax[1].bar(bins1[1:4], hist1[:3], fc='teal',width=0.1, ec='.2')
ax[1].bar(bins1[4:9], hist1[3:8], fc='orange',width=0.1, ec='.2')
ax[1].bar(bins1[9:], hist1[8:], fc='crimson',width=0.1, ec='.2')
ax[1].set_yscale('log')
plt.show()

# %% [markdown]
# # Drugs and Natural Compounds

# %%
# Degree bins - Unseen Edges 

# %matplotlib inline

means1 = np.array([0.80,0.82])
stdvs1 = np.array([0.0105,0.0242])

means2 = np.array([0.83,0.95])
stdvs2 = np.array([0.0079,0.0104])

fig, ax = plt.subplots(1,1,figsize=(3,3), dpi=300)
ax.hlines(list(range(len(means1))), means1-(stdvs1),
          means1+(stdvs1), color='crimson')
ax.scatter(means1, list(range(len(means1))), marker='s', s=10,
           color='crimson', label='ROC-AUC', ec='.1', zorder=2)
ax.hlines(np.array(list(range(len(means2))))-0.2,
          means2-(stdvs2), means2+(stdvs2),
          color='darksalmon')
ax.scatter(means2, np.array(list(range(len(means2))))-0.2,
           marker='s', s=10, color='darksalmon', label='Average Precision', ec='.1', zorder=2)
for mi,m in enumerate(means1):
    ax.text((means1-(stdvs1)/((means1)**.5))[mi]-0.025, list(range(len(means1)))[mi],
           m, ha='right', va='center',color='crimson', path_effects=[path_effects.Stroke(linewidth=1.5, foreground='w'),
                           path_effects.Normal()])
for mi,m in enumerate(means2):
    ax.text((means2-(stdvs2)/((means2)**.5))[mi]-0.025, list(range(len(means2)))[mi]-0.2,
           m, ha='right', va='center',color='darksalmon', path_effects=[path_effects.Stroke(linewidth=1.5, foreground='w'),
                           path_effects.Normal()])
# ax.legend(loc=2, bbox_to_anchor=[0.1, -0.125], ncol=2, framealpha=0)
ax.set_yticks([-0.1,0.9])
ax.set_yticklabels(['Drugs','Natural Compounds'])
ax.grid(axis='x', lw=1.5, alpha=0.3, color='.75')
ax.set_xlabel('Performance')
ax.set_xlim(0,1)
plt.show()

# %%
# Degree bins - Unseen Targets 

# %matplotlib inline

means1 = np.array([0.66,0.70])
stdvs1 = np.array([0.0294,0.0411])

means2 = np.array([0.67,0.91])
stdvs2 = np.array([0.0187,0.0322])

fig, ax = plt.subplots(1,1,figsize=(3,3), dpi=300)
ax.hlines(list(range(len(means1))), means1-(stdvs1),
          means1+(stdvs1), color='crimson')
ax.scatter(means1, list(range(len(means1))), marker='s', s=10,
           color='crimson', label='ROC-AUC', ec='.1', zorder=2)
ax.hlines(np.array(list(range(len(means2))))-0.2,
          means2-(stdvs2), means2+(stdvs2),
          color='darksalmon')
ax.scatter(means2, np.array(list(range(len(means2))))-0.2,
           marker='s', s=10, color='darksalmon', label='Average Precision', ec='.1', zorder=2)
for mi,m in enumerate(means1):
    ax.text((means1-(stdvs1)/((means1)**.5))[mi]-0.025, list(range(len(means1)))[mi],
           m, ha='right', va='center',color='crimson', path_effects=[path_effects.Stroke(linewidth=1.5, foreground='w'),
                           path_effects.Normal()])
for mi,m in enumerate(means2):
    ax.text((means2-(stdvs2)/((means2)**.5))[mi]-0.025, list(range(len(means2)))[mi]-0.2,
           m, ha='right', va='center',color='darksalmon', path_effects=[path_effects.Stroke(linewidth=1.5, foreground='w'),
                           path_effects.Normal()])
# ax.legend(loc=2, bbox_to_anchor=[0.1, -0.125], ncol=2, framealpha=0)
ax.set_yticks([-0.1,0.9])
ax.set_yticklabels(['Drugs','Natural Compounds'])
ax.grid(axis='x', lw=1.5, alpha=0.3, color='.75')
ax.set_xlabel('Performance')
ax.set_xlim(0,1)
plt.show()

# %% [markdown]
# # New Results

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patheffects as path_effects
import pandas as pd

# %% [markdown]
# ## Unseen Nodes

# %%
vecnet_auc = [0.742,0.029]
vecnet_aup = [0.724,0.037]

config_auc = [0.5,0.0]
config_aup = [0.469,0.014]

deeppurpose_auc = [0.642,0.025]
deeppurpose_aup = [0.583,0.016]

# %%
perf_df = pd.DataFrame()

perf_df['Model'] = ['Configuration Model', 'DeepPurpose', 'VecNet']
perf_df['AUC-Mean'] = [config_auc[0],deeppurpose_auc[0],vecnet_auc[0]]
perf_df['AUC-SD'] = [config_auc[1],deeppurpose_auc[1],vecnet_auc[1]]
perf_df['AUP-Mean'] = [config_aup[0],deeppurpose_aup[0],vecnet_aup[0]]
perf_df['AUP-SD'] = [config_aup[1],deeppurpose_aup[1],vecnet_aup[1]]

# %%
# Numbers of pairs of bars you want
N = 3

# Data on X-axis

# Specify the values of blue bars (height)
blue_bar = perf_df['AUC-Mean']
# Specify the values of orange bars (height)
orange_bar = perf_df['AUP-Mean']

# Position of bars on x-axis
ind = np.arange(N)

# Figure size
plt.figure(figsize=(7,5))

# Width of a bar 
width = 0.3      

plt.ylim([0,1.0])

# Plotting
plt.bar(ind, blue_bar, width ,label='AUROC') 
plt.bar(ind + width, orange_bar, width, label='AUPRC') 

plt.errorbar(ind, blue_bar,yerr=perf_df['AUC-SD'], fmt='o', color='Black', elinewidth=3,capthick=3,errorevery=1, alpha=1, ms=4, capsize = 5)
plt.errorbar(ind + width, orange_bar,yerr=perf_df['AUP-SD'], fmt='o', color='Black', elinewidth=3,capthick=3,errorevery=1, alpha=1, ms=4, capsize = 5)

plt.xlabel('Models')
plt.ylabel('Average Performance')
plt.title('Unseen Nodes')

# xticks()
# First argument - A list of positions at which ticks should be placed
# Second argument -  A list of labels to place at the given locations
plt.xticks(ind + width / 2, perf_df['Model'])

# Finding the best position for legends and putting it
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Unseen Targets

# %%
vecnet_auc = [0.778,0.02]
vecnet_aup = [0.758,0.03]

config_auc = [0.738,0.014]
config_aup = [0.705,0.01]

deeppurpose_auc = [0.642,0.02]
deeppurpose_aup = [0.591,0.0426]

# %%
perf_df = pd.DataFrame()

perf_df['Model'] = ['Configuration Model', 'DeepPurpose', 'VecNet']
perf_df['AUC-Mean'] = [config_auc[0],deeppurpose_auc[0],vecnet_auc[0]]
perf_df['AUC-SD'] = [config_auc[1],deeppurpose_auc[1],vecnet_auc[1]]
perf_df['AUP-Mean'] = [config_aup[0],deeppurpose_aup[0],vecnet_aup[0]]
perf_df['AUP-SD'] = [config_aup[1],deeppurpose_aup[1],vecnet_aup[1]]

# Numbers of pairs of bars you want
N = 3

# Data on X-axis

# Specify the values of blue bars (height)
blue_bar = perf_df['AUC-Mean']
# Specify the values of orange bars (height)
orange_bar = perf_df['AUP-Mean']

# Position of bars on x-axis
ind = np.arange(N)

# Figure size
plt.figure(figsize=(7,5))

# Width of a bar 
width = 0.3       

plt.ylim([0,1.0])

# Plotting
plt.bar(ind, blue_bar, width ,label='AUROC') 
plt.bar(ind + width, orange_bar, width, label='AUPRC') 

plt.errorbar(ind, blue_bar,yerr=perf_df['AUC-SD'], fmt='o', color='Black', elinewidth=3,capthick=3,errorevery=1, alpha=1, ms=4, capsize = 5)
plt.errorbar(ind + width, orange_bar,yerr=perf_df['AUP-SD'], fmt='o', color='Black', elinewidth=3,capthick=3,errorevery=1, alpha=1, ms=4, capsize = 5)

plt.xlabel('Models')
plt.ylabel('Average Performance')
plt.title('Unseen Targets')

# xticks()
# First argument - A list of positions at which ticks should be placed
# Second argument -  A list of labels to place at the given locations
plt.xticks(ind + width / 2, perf_df['Model'])

# Finding the best position for legends and putting it
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Unseen Edges

# %%
vecnet_auc = [0.792, 0.009]
vecnet_aup = [0.814,0.014]

config_auc = [0.722,0.015]
config_aup = [0.736,0.016]

deeppurpose_auc = [0.775,0.025]
deeppurpose_aup = [0.800,0.025]

# %%
perf_df = pd.DataFrame()

perf_df['Model'] = ['Configuration Model', 'DeepPurpose', 'VecNet']
perf_df['AUC-Mean'] = [config_auc[0],deeppurpose_auc[0],vecnet_auc[0]]
perf_df['AUC-SD'] = [config_auc[1],deeppurpose_auc[1],vecnet_auc[1]]
perf_df['AUP-Mean'] = [config_aup[0],deeppurpose_aup[0],vecnet_aup[0]]
perf_df['AUP-SD'] = [config_aup[1],deeppurpose_aup[1],vecnet_aup[1]]

# Numbers of pairs of bars you want
N = 3

# Data on X-axis

# Specify the values of blue bars (height)
blue_bar = perf_df['AUC-Mean']
# Specify the values of orange bars (height)
orange_bar = perf_df['AUP-Mean']

# Position of bars on x-axis
ind = np.arange(N)

# Figure size
plt.figure(figsize=(7,5))

# Width of a bar 
width = 0.3       

plt.ylim([0,1.0])

# Plotting
plt.bar(ind, blue_bar, width ,label='AUROC') 
plt.bar(ind + width, orange_bar, width, label='AUPRC') 

plt.errorbar(ind, blue_bar,yerr=perf_df['AUC-SD'], fmt='o', color='Black', elinewidth=3,capthick=3,errorevery=1, alpha=1, ms=4, capsize = 5)
plt.errorbar(ind + width, orange_bar,yerr=perf_df['AUP-SD'], fmt='o', color='Black', elinewidth=3,capthick=3,errorevery=1, alpha=1, ms=4, capsize = 5)

plt.xlabel('Models')
plt.ylabel('Average Performance')
plt.title('Unseen Edges')

# xticks()
# First argument - A list of positions at which ticks should be placed
# Second argument -  A list of labels to place at the given locations
plt.xticks(ind + width / 2, perf_df['Model'])

# Finding the best position for legends and putting it
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Unseen Nodes - DrugBank VS NDM

# %%
drugbank_auc = [0.738,0.031]
drugbank_aup = [0.72,0.04]

ncfd_auc = [0.744,0.055]
ncfd_aup = [0.889,0.038]

# %%
perf_df = pd.DataFrame()

perf_df['Model'] = ['Drugs', 'Natural Compounds']
perf_df['AUC-Mean'] = [drugbank_auc[0],ncfd_auc[0]]
perf_df['AUC-SD'] = [drugbank_auc[1],ncfd_auc[1]]
perf_df['AUP-Mean'] = [drugbank_aup[0],ncfd_aup[0]]
perf_df['AUP-SD'] = [drugbank_aup[1],ncfd_aup[1]]

# %%
# Numbers of pairs of bars you want
N = 2

# Data on X-axis

# Specify the values of blue bars (height)
blue_bar = perf_df['AUC-Mean']
# Specify the values of orange bars (height)
orange_bar = perf_df['AUP-Mean']

# Position of bars on x-axis
ind = np.arange(N)

# Figure size
plt.figure(figsize=(7,5))

# Width of a bar 
width = 0.3       

plt.ylim([0,1.0])

# Plotting
plt.bar(ind, blue_bar, width ,label='AUROC') 
plt.bar(ind + width, orange_bar, width, label='AUPRC') 

plt.errorbar(ind, blue_bar,yerr=perf_df['AUC-SD'], fmt='o', color='Black', elinewidth=3,capthick=3,errorevery=1, alpha=1, ms=4, capsize = 5)
plt.errorbar(ind + width, orange_bar,yerr=perf_df['AUP-SD'], fmt='o', color='Black', elinewidth=3,capthick=3,errorevery=1, alpha=1, ms=4, capsize = 5)

plt.xlabel('Ligand Type')
plt.ylabel('Average Performance')
plt.title('Unseen Nodes')

# xticks()
# First argument - A list of positions at which ticks should be placed
# Second argument -  A list of labels to place at the given locations
plt.xticks(ind + width / 2, perf_df['Model'])

# Finding the best position for legends and putting it
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## DeepPurpose and Config Model

# %%
perf_df = pd.DataFrame()

perf_df['Model'] = ['DeepPurpose', 'Configuration Model']
perf_df['AUC-Mean'] = [0.85,0.85]
perf_df['AUP-Mean'] = [0.63,0.62]

# %%
# Numbers of pairs of bars you want
N = 2

# Data on X-axis

# Specify the values of blue bars (height)
blue_bar = perf_df['AUC-Mean']
# Specify the values of orange bars (height)
orange_bar = perf_df['AUP-Mean']

# Position of bars on x-axis
ind = np.arange(N)

# Figure size
plt.figure(figsize=(7,5))

# Width of a bar 
width = 0.3       

plt.ylim([0,1.0])

# Plotting
plt.bar(ind, blue_bar, width ,label='AUROC') 
plt.bar(ind + width, orange_bar, width, label='AUPRC') 

#plt.errorbar(ind, blue_bar,yerr=perf_df['AUC-SD'], fmt='o', color='Black', elinewidth=3,capthick=3,errorevery=1, alpha=1, ms=4, capsize = 5)
#plt.errorbar(ind + width, orange_bar,yerr=perf_df['AUP-SD'], fmt='o', color='Black', elinewidth=3,capthick=3,errorevery=1, alpha=1, ms=4, capsize = 5)

plt.xlabel('Model')
plt.ylabel('Performance')
plt.title('Overall')

# xticks()
# First argument - A list of positions at which ticks should be placed
# Second argument -  A list of labels to place at the given locations
plt.xticks(ind + width / 2, perf_df['Model'])

# Finding the best position for legends and putting it
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Break down of DeepPurpose Performance

# %%
perf_df = pd.DataFrame()

perf_df['Test'] = ['Unseen Edges', 'Unseen Targets', 'Unseen Nodes']
perf_df['AUC-Mean'] = [0.84,0.80,0.5]
perf_df['AUP-Mean'] = [0.52,0.75,0.35]

# %%
# Numbers of pairs of bars you want
N = 3

# Data on X-axis

# Specify the values of blue bars (height)
blue_bar = perf_df['AUC-Mean']
# Specify the values of orange bars (height)
orange_bar = perf_df['AUP-Mean']

# Position of bars on x-axis
ind = np.arange(N)

# Figure size
plt.figure(figsize=(7,5))

# Width of a bar 
width = 0.3       

plt.ylim([0,1.0])

# Plotting
plt.bar(ind, blue_bar, width ,label='AUROC') 
plt.bar(ind + width, orange_bar, width, label='AUPRC') 

#plt.errorbar(ind, blue_bar,yerr=perf_df['AUC-SD'], fmt='o', color='Black', elinewidth=3,capthick=3,errorevery=1, alpha=1, ms=4, capsize = 5)
#plt.errorbar(ind + width, orange_bar,yerr=perf_df['AUP-SD'], fmt='o', color='Black', elinewidth=3,capthick=3,errorevery=1, alpha=1, ms=4, capsize = 5)

plt.xlabel('Test')
plt.ylabel('Performance')
plt.title('Different Tests')

# xticks()
# First argument - A list of positions at which ticks should be placed
# Second argument -  A list of labels to place at the given locations
plt.xticks(ind + width / 2, perf_df['Test'])

# Finding the best position for legends and putting it
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# # Cross-Validation on DeepPurpose and Duplex Configuration Model

# %%
deeppurpose_overall_auc = [0.85,0.86,0.86,0.86,0.85]
deeppurpose_overall_aup = [0.63,0.64,0.65,0.65,0.65]

deeppurpose_unseen_edges_auc = [0.82,0.81,0.82,0.82,0.82]
deeppurpose_unseen_edges_aup = [0.48,0.49,0.48,0.48,0.48]

deeppurpose_unseen_targets_auc = [0.79,0.81,0.74,0.71,0.74]
deeppurpose_unseen_targets_aup = [0.78,0.77,0.65,0.63,0.65]

deeppurpose_unseen_nodes_auc = [0.49,0.58,0.68,0.64,0.64]
deeppurpose_unseen_nodes_aup = [0.36,0.36,0.53,0.44,0.44]

duplex_overall_auc = [0.86,0.85,0.86,0.85,0.86]
duplex_overall_aup = [0.63,0.61,0.61,0.61,0.61]

duplex_unseen_edges_auc = [0.82,0.82,0.84,0.84,0.84]
duplex_unseen_edges_aup = [0.52,0.50,0.49,0.49,0.50]

duplex_unseen_targets_auc = [0.80,0.82,0.82,0.72,0.71]
duplex_unseen_targets_aup = [0.75,0.77,0.77,0.63,0.63]

duplex_unseen_nodes_auc = [0.5,0.5,0.5,0.5,0.5]
duplex_unseen_nodes_aup = [0.35,0.27,0.26,0.32,0.32]

# %%
deeppurpose_overall_auc_mean_std = [np.mean(deeppurpose_overall_auc), np.std(deeppurpose_overall_auc)]
deeppurpose_overall_aup_mean_std = [np.mean(deeppurpose_overall_aup), np.std(deeppurpose_overall_aup)]

deeppurpose_unseen_edges_auc_mean_std = [np.mean(deeppurpose_unseen_edges_auc), np.std(deeppurpose_unseen_edges_auc)]
deeppurpose_unseen_edges_aup_mean_std = [np.mean(deeppurpose_unseen_edges_aup), np.std(deeppurpose_unseen_edges_aup)]

deeppurpose_unseen_targets_auc_mean_std = [np.mean(deeppurpose_unseen_targets_auc), np.std(deeppurpose_unseen_targets_auc)]
deeppurpose_unseen_targets_aup_mean_std = [np.mean(deeppurpose_unseen_targets_aup), np.std(deeppurpose_unseen_targets_aup)]

deeppurpose_unseen_nodes_auc_mean_std = [np.mean(deeppurpose_unseen_nodes_auc), np.std(deeppurpose_unseen_nodes_auc)]
deeppurpose_unseen_nodes_aup_mean_std = [np.mean(deeppurpose_unseen_nodes_aup), np.std(deeppurpose_unseen_nodes_aup)]


duplex_overall_auc_mean_std = [np.mean(duplex_overall_auc), np.std(duplex_overall_auc)]
duplex_overall_aup_mean_std = [np.mean(duplex_overall_aup), np.std(duplex_overall_aup)]

duplex_unseen_edges_auc_mean_std = [np.mean(duplex_unseen_edges_auc), np.std(duplex_unseen_edges_auc)]
duplex_unseen_edges_aup_mean_std = [np.mean(duplex_unseen_edges_aup), np.std(duplex_unseen_edges_aup)]

duplex_unseen_targets_auc_mean_std = [np.mean(duplex_unseen_targets_auc), np.std(duplex_unseen_targets_auc)]
duplex_unseen_targets_aup_mean_std = [np.mean(duplex_unseen_targets_aup), np.std(duplex_unseen_targets_aup)]

duplex_unseen_nodes_auc_mean_std = [np.mean(duplex_unseen_nodes_auc), np.std(duplex_unseen_nodes_auc)]
duplex_unseen_nodes_aup_mean_std = [np.mean(duplex_unseen_nodes_aup), np.std(duplex_unseen_nodes_aup)]

# %%
perf_df = pd.DataFrame()

perf_df['Model'] = ['DeepPurpose', 'Configuration Model']
perf_df['AUC-Mean'] = [deeppurpose_overall_auc_mean_std[0],duplex_overall_auc_mean_std[0]]
perf_df['AUC-SD'] = [deeppurpose_overall_auc_mean_std[1],duplex_overall_auc_mean_std[1]]
perf_df['AUP-Mean'] = [deeppurpose_overall_aup_mean_std[0],duplex_overall_aup_mean_std[0]]
perf_df['AUP-SD'] = [deeppurpose_overall_aup_mean_std[1],duplex_overall_aup_mean_std[1]]

# %%
# Numbers of pairs of bars you want
N = 2

# Data on X-axis

# Specify the values of blue bars (height)
blue_bar = perf_df['AUC-Mean']
# Specify the values of orange bars (height)
orange_bar = perf_df['AUP-Mean']

# Position of bars on x-axis
ind = np.arange(N)

# Figure size
plt.figure(figsize=(7,5))

# Width of a bar 
width = 0.3       

plt.ylim([0,1.0])

# Plotting
plt.bar(ind, blue_bar, width ,label='AUROC') 
plt.bar(ind + width, orange_bar, width, label='AUPRC') 

plt.errorbar(ind, blue_bar,yerr=perf_df['AUC-SD'], fmt='o', color='Black', elinewidth=3,capthick=3,errorevery=1, alpha=1, ms=4, capsize = 5)
plt.errorbar(ind + width, orange_bar,yerr=perf_df['AUP-SD'], fmt='o', color='Black', elinewidth=3,capthick=3,errorevery=1, alpha=1, ms=4, capsize = 5)

plt.xlabel('Model')
plt.ylabel('Average Performance')
plt.title('Overall')

# xticks()
# First argument - A list of positions at which ticks should be placed
# Second argument -  A list of labels to place at the given locations
plt.xticks(ind + width / 2, perf_df['Model'])

# Finding the best position for legends and putting it
plt.legend(loc='upper right')
plt.show()

# %%
perf_df = pd.DataFrame()

perf_df['Model'] = ['Unseen Edges', 'Unseen Targets', 'Unseen Nodes']
perf_df['AUC-Mean'] = [deeppurpose_unseen_edges_auc_mean_std[0],deeppurpose_unseen_targets_auc_mean_std[0],deeppurpose_unseen_nodes_auc_mean_std[0]]
perf_df['AUC-SD'] = [deeppurpose_unseen_edges_auc_mean_std[1],deeppurpose_unseen_targets_auc_mean_std[1],deeppurpose_unseen_nodes_auc_mean_std[1]]
perf_df['AUP-Mean'] = [deeppurpose_unseen_edges_aup_mean_std[0],deeppurpose_unseen_targets_aup_mean_std[0],deeppurpose_unseen_nodes_aup_mean_std[0]]
perf_df['AUP-SD'] = [deeppurpose_unseen_edges_aup_mean_std[1],deeppurpose_unseen_targets_aup_mean_std[1],deeppurpose_unseen_nodes_aup_mean_std[1]]

# Numbers of pairs of bars you want
N = 3

# Data on X-axis

# Specify the values of blue bars (height)
blue_bar = perf_df['AUC-Mean']
# Specify the values of orange bars (height)
orange_bar = perf_df['AUP-Mean']

# Position of bars on x-axis
ind = np.arange(N)

# Figure size
plt.figure(figsize=(7,5))

# Width of a bar 
width = 0.3       

plt.ylim([0,1.0])

# Plotting
plt.bar(ind, blue_bar, width ,label='AUROC') 
plt.bar(ind + width, orange_bar, width, label='AUPRC') 

plt.errorbar(ind, blue_bar,yerr=perf_df['AUC-SD'], fmt='o', color='Black', elinewidth=3,capthick=3,errorevery=1, alpha=1, ms=4, capsize = 5)
plt.errorbar(ind + width, orange_bar,yerr=perf_df['AUP-SD'], fmt='o', color='Black', elinewidth=3,capthick=3,errorevery=1, alpha=1, ms=4, capsize = 5)

plt.xlabel('Tests')
plt.ylabel('Average Performance of DeepPurpose')
plt.title('Different Tests')

# xticks()
# First argument - A list of positions at which ticks should be placed
# Second argument -  A list of labels to place at the given locations
plt.xticks(ind + width / 2, perf_df['Model'])

# Finding the best position for legends and putting it
plt.legend(loc='upper right')
plt.show()

# %%
perf_df = pd.DataFrame()

perf_df['Model'] = ['Unseen Edges', 'Unseen Targets', 'Unseen Nodes']
perf_df['AUC-Mean'] = [duplex_unseen_edges_auc_mean_std[0],duplex_unseen_targets_auc_mean_std[0],duplex_unseen_nodes_auc_mean_std[0]]
perf_df['AUC-SD'] = [duplex_unseen_edges_auc_mean_std[1],duplex_unseen_targets_auc_mean_std[1],duplex_unseen_nodes_auc_mean_std[1]]
perf_df['AUP-Mean'] = [duplex_unseen_edges_aup_mean_std[0],duplex_unseen_targets_aup_mean_std[0],duplex_unseen_nodes_aup_mean_std[0]]
perf_df['AUP-SD'] = [duplex_unseen_edges_aup_mean_std[1],duplex_unseen_targets_aup_mean_std[1],duplex_unseen_nodes_aup_mean_std[1]]

# Numbers of pairs of bars you want
N = 3

# Data on X-axis

# Specify the values of blue bars (height)
blue_bar = perf_df['AUC-Mean']
# Specify the values of orange bars (height)
orange_bar = perf_df['AUP-Mean']

# Position of bars on x-axis
ind = np.arange(N)

# Figure size
plt.figure(figsize=(7,5))

# Width of a bar 
width = 0.3       

plt.ylim([0,1.0])

# Plotting
plt.bar(ind, blue_bar, width ,label='AUROC') 
plt.bar(ind + width, orange_bar, width, label='AUPRC') 

plt.errorbar(ind, blue_bar,yerr=perf_df['AUC-SD'], fmt='o', color='Black', elinewidth=3,capthick=3,errorevery=1, alpha=1, ms=4, capsize = 5)
plt.errorbar(ind + width, orange_bar,yerr=perf_df['AUP-SD'], fmt='o', color='Black', elinewidth=3,capthick=3,errorevery=1, alpha=1, ms=4, capsize = 5)

plt.xlabel('Tests')
plt.ylabel('Average Performance of Configuration Model')
plt.title('Different Tests')

# xticks()
# First argument - A list of positions at which ticks should be placed
# Second argument -  A list of labels to place at the given locations
plt.xticks(ind + width / 2, perf_df['Model'])

# Finding the best position for legends and putting it
plt.legend(loc='upper right')
plt.show()

# %%
original_auc = [0.85,0.86,0.86,0.86,0.85]
original_aup = [0.63,0.64,0.65,0.65,0.65]

random_shuffle_auc = [0.84,0.84,0.84,0.84,0.84]
random_shuffle_aup = [0.61,0.62,0.62,0.62,0.62]

# %%
print('Original AUC mean and std: ', np.mean(original_auc), np.std(original_auc))
print('Original AUp mean and std: ', np.mean(original_aup), np.std(original_aup))

print('Randomized AUC mean and std: ', np.mean(original_auc), np.std(original_auc))
print('Randomized AUp mean and std: ', np.mean(original_aup), np.std(original_aup))
# Out:
# Original AUC mean and std:  0.8559999999999999 0.004898979485566361
# Original AUp mean and std:  0.6439999999999999 0.008000000000000007
# Randomized AUC mean and std:  0.8559999999999999 0.004898979485566361
# Randomized AUp mean and std:  0.6439999999999999 0.008000000000000007
